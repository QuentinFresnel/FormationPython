# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2000', periods=1000))

ts = ts.cumsum()

# %%
ts.plot()

# %%
print('Allez git, marche stp')
# Out:
# Allez git, marche stp

# %%
print('Allez quoi')
# Out:
# Allez quoi
